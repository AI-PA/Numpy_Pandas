# %% [markdown]
# # Shape y Reshape
#
# - *Shape : Muestra* forma que tiene el array.
# - **Reshape : Cambia** la forma del array
#
# ***Nota***: Deben tener la misma cantidad de valores.

# %%
import numpy as np

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[2, 9],
#        [9, 4],
#        [9, 3]])

# %%
arr.shape # Muestra las dimensiones del array en este caso 3x2 que es la que definimos en la parte de arriba.
# Out:
# (3, 2)

# %%
np.reshape(arr,(2,3)) #(np-array, dimension)
# Modifica la dimension del array para adaptarse al parámetro
# Out:
# array([[2, 9, 9],
#        [4, 9, 3]])

# %%
arr
# Out:
# array([[2, 9],
#        [9, 4],
#        [9, 3]])

# %%
np.reshape(arr,(6,1),"C") 
# Reorganiza el array de acuerdo a la forma del Lenguaje C 
# Todas las Filas hasta terminar y sigue con la otra fila.
# Out:
# array([[2],
#        [9],
#        [9],
#        [4],
#        [9],
#        [3]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.reshape(arr,(6,1),"F")
# Reorganiza el array de acuerdo a la forma del Lenguaje Fortran
# Toda la columna y después continua con la otra columna.
# Out:
# array([[2],
#        [9],
#        [9],
#        [9],
#        [4],
#        [3]])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
np.reshape(arr,(6,1),"A")
# Reorganiza el array de acuerdo a como sea mas optimizado para nuestro sistema. 
# Puede ser C o F.
# Out:
# array([[2],
#        [9],
#        [9],
#        [4],
#        [9],
#        [3]])

# %% [markdown]
# ## Reto
#
# - Crear un array de cualquier dimension y cambiar sus dimensiones.
# - Intenta cambiar el array de forma que no respete la estructura original

# %%
arr3 = np.eye(3)
arr3
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# ### Cambiar sus dimensiones

# %%
np.reshape(arr3,(1,9))
# En el caso de la matriz identidad de igual si es F o C sera la misma.
# Out:
# array([[1., 0., 0., 0., 1., 0., 0., 0., 1.]])

# %% [markdown]
# ### Cambiar a forma que no respete su estructura original

# %%
np.reshape(arr3,(2,2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 np.reshape(arr3,(2,2))
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:285, in reshape(a, newshape, order)
#     200 @array_function_dispatch(_reshape_dispatcher)
#     201 def reshape(a, newshape, order='C'):
#     202     """
#     203     Gives a new shape to an array without changing its data.
#     204
#    (...)
#     283            [5, 6]])
#     284     """
# --> 285     return _wrapfunc(a, 'reshape', newshape, order=order)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59, in _wrapfunc(obj, method, *args, **kwds)
#      56     return _wrapit(obj, method, *args, **kwds)
#      58 try:
# ---> 59     return bound(*args, **kwds)
#      60 except TypeError:
#      61     # A TypeError occurs if the object does have such a method in its
# ...
